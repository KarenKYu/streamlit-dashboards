# %%
import pandas as pd

# %%
df = pd.read_csv('./imdb_movies.csv')

# %%
df[:2]
# Out:
#                                       title      genre     budget  runtime  \
# 0                                    Avatar     Action  237000000    162.0
# 1  Pirates of the Caribbean: At World's End  Adventure  300000000    169.0
#
#    year  month     revenue
# 0  2009     12  2787965087
# 1  2007      5   961000000

# %%
import sqlite3
conn = sqlite3.connect('imdb.db')

# %%
df.to_sql('movies', conn, index_label = 'id')

# %%
pd.read_sql('select * from movies', conn)
# Out:
#         id                                        title            genre  \
# 0        0                                       Avatar           Action
# 1        1     Pirates of the Caribbean: At World's End        Adventure
# 2        2                                      Spectre           Action
# 3        3                        The Dark Knight Rises           Action
# 4        4                                  John Carter           Action
# 5        5                                 Spider-Man 3          Fantasy
# 6        6                                      Tangled        Animation
# 7        7                      Avengers: Age of Ultron           Action
# 8        8       Harry Potter and the Half-Blood Prince        Adventure
# 9        9           Batman v Superman: Dawn of Justice           Action
# 10      10                             Superman Returns        Adventure
# 11      11                            Quantum of Solace        Adventure
# ...
